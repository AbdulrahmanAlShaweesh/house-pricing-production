# %% [markdown]
# # Loading the needs Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
import sklearn.datasets  
from sklearn.model_selection import train_test_split

# %%
warnings.filterwarnings('ignore') 
# %matplotlib inline

# %%
house_price_dataset = sklearn.datasets.fetch_california_housing()

# %%
house_price_df = pd.DataFrame(data=house_price_dataset.data, columns=house_price_dataset.feature_names)

# %%
house_price_df['SalePrice'] = house_price_dataset.target

# %% [markdown]
# ## type of the datase read from sklearn library

# %%
type(house_price_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# ## Type of data frame read from pandas Library

# %%
type(house_price_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## The first 5 rows in the dataset

# %%
first_5_rows = house_price_df.head()
first_5_rows
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  SalePrice
# 0    -122.23      4.526
# 1    -122.22      3.585
# 2    -122.24      3.521
# 3    -122.25      3.413
# 4    -122.25      3.422

# %% [markdown]
# ## The last 5 rows in the dataset

# %%
last_5_rows = house_price_df.tail()

# %%
pd.options.display.min_rows = 100

# %% [markdown]
# ## The first 40 rows in the dataset

# %%
house_price_df.head(25).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_a656b_row0_col0, #T_a656b_row0_col6, #T_a656b_row0_col8, #T_a656b_row1_col0, #T_a656b_row1_col4, #T_a656b_row1_col7, #T_a656b_row2_col1, #T_a656b_row2_col2, #T_a656b_row2_col5, #T_a656b_row3_col1, #T_a656b_row4_col1, #T_a656b_row5_col1, #T_a656b_row6_col1, #T_a656b_row7_col1, #T_a656b_row9_col1, #T_a656b_row10_col1, #T_a656b_row11_col1, #T_a656b_row12_col1, #T_a656b_row13_col1, #T_a656b_row14_col1, #T_a656b_row16_col1, #T_a656b_row17_col1, #T_a656b_row19_col1, #T_a656b_row22_col1, #T_a656b_row22_col3, #T_a656b_row23_col1, #T_a656b_row24_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a656b_row0_col1 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_a656b_row0_col2 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_a656b_row0_col3, #T_a656b_row3_col7, #T_a656b_row4_col7, #T_a656b_row5_col7, #T_a656b_row6_col7, #T_a656b_row7_col4, #T_a656b_row7_col7, #T_a656b_row7_col8, #T_a656b_row9_col7 {
# ...

# %% [markdown]
# ## Shown some statistical measurement

# %%
house_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   SalePrice   20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# ## type of the data for each columns

# %%
house_price_df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# SalePrice     float64
# dtype: object

# %% [markdown]
# ## Shown some statistical measurement

# %%
house_price_df.describe().style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_420d3_row0_col0, #T_420d3_row0_col1, #T_420d3_row0_col2, #T_420d3_row0_col3, #T_420d3_row0_col5, #T_420d3_row0_col6, #T_420d3_row0_col7, #T_420d3_row0_col8, #T_420d3_row7_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_420d3_row0_col4 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## The total null value in each column

# %%
plt.scatter(house_price_df['HouseAge'], house_price_df['SalePrice'])
